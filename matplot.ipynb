# %%
import numpy as np
import matplotlib.pyplot as plt

x = ["a","b","111111111111c","33333333333d","e","f","g","h","i11111111"]
y = [1,0,1,2,3,1,1,1,1]
fig, ax = plt.subplots()
ax.set_xlabel("scenario name")
ax.set_ylabel("diff count")
ax.bar(x, y)
# Out:
# <BarContainer object of 9 artists>
